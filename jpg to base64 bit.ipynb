# %%
from PIL import Image
import base64

# %%
with open("Intel Pentium Gold G7400 Alder Lake Processor.jpg", "rb") as f:
    image = Image.open(f)

# %%
import base64
# Convert the image to base64 format
with open("Intel Pentium Gold G7400 Alder Lake Processor.jpg", "rb") as f:
    encoded_image = base64.b64encode(f.read())

# %%
print(encoded_image)
# Out:
# b'...'
